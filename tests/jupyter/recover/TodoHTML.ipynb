# %%
import os

os.environ["SYNC_FILE"] = "file.bin"
from todoapp import TodoApp, state  # noqa

app = TodoApp()
# Out:
# /Users/perceval/Development/pret/tests/jupyter/recover/todoapp.py:6: UserWarning: Initial data provided to create_store will be ignored since the file file.bin already exists. Prefer passing data as a function  that returns the initial data if you want to ensure it is only used when the file doesn't exist. Alternatively, you may also prefer load_store_snapshot to load the data from an existing file.
#   state = create_store(

# %%
app
